# %% [markdown]
# # Task 3 - Lambda Function :GST calculater

# %% [markdown]
# ## Create a lambda function gst that returns price after adding 18% gst.

# %%
gst = lambda price: price + (price * 0.18)

# %%
print(gst(1000))
# Out:
# 1180.0
