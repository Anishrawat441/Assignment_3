# %% [markdown]
# # Task 4- Using map(): Apply GST to list of Prices

# %% [markdown]
# ## Given:
# ## Prices = [ 100, 250, 400, 1200, 50]

# %%
# Use map () with your gst lambda to generate a new list prices_with_gst.

prices = [100, 250, 400, 1200, 50]
prices_with_gst = map(lambda price: price + (price * 0.18),prices)
print(prices_with_gst)

# %%
# Print both lists:
# original prices

print(prices)

# %%
print(prices_with_gst)
