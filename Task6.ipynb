# %% [markdown]
# # Task 6 - Combined Utility Function

# %% [markdown]
# ## Write a function process_prices(prices)that:
# ### 1.Takes a list of prices.
# ### 2. Uses map()+lambda to apply 10% discount to all prices.
# ### 3. Uses Filter() to keep only discounted prices that are above 300.
# ### 4. Returns both lists: discounted prices, filtered_prices

# %%
def process_prices(prices):
    # 1. Apply 10% discount using map() + lambda
    discounted_prices = list(map(lambda p: p - (p * 0.10), prices))
    
    # 2. Filter prices above 300
    filtered_prices = list(filter(lambda p: p > 300, discounted_prices))
    
    # 3. Return both lists
    return discounted_prices, filtered_prices

# %%
prices=(100, 500, 900, 50, 750])

discounted, filtered = process_prices(prices)

print("Discounted Prices:", discounted)
print("Filtered Prices (>300):", filtered)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 prices([100, 500, 900, 50, 750])
#       3 discounted, filtered = process_prices(prices)
#       5 print("Discounted Prices:", discounted)
#
# NameError: name 'prices' is not defined
